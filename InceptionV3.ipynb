# %% [markdown]
# # Artificial Neural Networks and Deep Learning
#
# ## I ragazzi del Bav
#
# #### Stefano Corti, Andrea Catelli, Alessandro Ciotti, Marco Giovanni Barbero
# ---
#
# ## Inception V3

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# %cd /gdrive/My Drive/ANN Homework 1/InceptionV3 finale
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/ANN Homework 1/InceptionV3 finale

# %% [markdown]
# ## ⚙️ Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import gc
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras import applications as tfk_apps
from tensorflow.keras import utils as tfk_utils
from tensorflow.keras.applications.inception_v3 import preprocess_input

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
from PIL import Image
import matplotlib.gridspec as gridspec
# !pip install keras-cv > /dev/null 2>&1
import keras_cv as kcv
import cv2

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.1

# %%
# Setting mixed precision
policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)

# %% [markdown]
# ## ⏳ Load Data

# %%
# Importing balanced dataset from which we get validation and test set
data = np.load("balanced_dataset.npz")
X_balanced = data['images']
y_balanced = data['labels']
print("Image shape: ", X_balanced.shape)
del data
gc.collect()

# Labels
labels = {0:"Basophil",1:"Eosinophil",2:"Erythroblast",3:"Immature granulocytes",4:"Lymphocyte",5:"Monocyte",6:"Neutrophil",7:"Platelet"}
# Out:
# Image shape:  (18640, 96, 96, 3)

# %% [markdown]
# ## 🔄 Process Data

# %%
# Split data into training, validation and test set, maintaining class distribution
X_train_val, X_test, y_train_val, y_test = train_test_split(X_balanced, y_balanced, random_state=seed, test_size=0.15, stratify=y_balanced)

# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=0.15, stratify=y_train_val)

del X_balanced, y_balanced, X_train_val, y_train_val
gc.collect()

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
print("Test Data Shape:", X_test.shape)
print("Test Label Shape:", y_test.shape)
# Out:
# Training Data Shape: (13467, 96, 96, 3)
# Training Label Shape: (13467,)
# Validation Data Shape: (2377, 96, 96, 3)
# Validation Label Shape: (2377,)
# Test Data Shape: (2796, 96, 96, 3)
# Test Label Shape: (2796,)

# %%
# Convert labels to categorical format using one-hot encoding
y_train = tfk.utils.to_categorical(y_train)
y_val = tfk.utils.to_categorical(y_val)
y_test = tfk.utils.to_categorical(y_test)

# Input shape for the model
input_shape = X_train.shape[1:]

# Output shape for the model
output_shape = y_train.shape[1]

# Target shape required for inception_v3
target_shape = 299

print("Input Shape:", input_shape)
print("Output Shape:", output_shape)
# Out:
# Input Shape: (96, 96, 3)
# Output Shape: 8

# %% [markdown]
# ## 🛠️ TRANSFER LEARNING

# %% [markdown]
# ## 🧮 Define Network Parameters

# %%
# Learning rate
initial_learning_rate = 0.001
tl_lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=10000,
    decay_rate=0.9)

# Optimazer
tl_Lion_optimizer = tfk.optimizers.Lion(learning_rate=tl_lr_schedule)

# Number of training epochs
tl_epochs = 150

# Batch size for training
tl_batch_size = 128

# Patience
tl_patience = 15


# Create an EarlyStopping callback
tl_callbacks = [
    tfk.callbacks.EarlyStopping(
        monitor='val_accuracy',
        mode='max',
        patience=tl_patience,
        restore_best_weights=True
    ),
    tfk.callbacks.ModelCheckpoint(
        filepath='best.weights.h5',
        save_best_only=True,
        save_weights_only=True,
        monitor='val_accuracy',
        mode='max',
        verbose=1
    )
]

# %% [markdown]
# ## 🛠️ Build the Model

# %%
# Importing the model
inception = tfk_apps.InceptionV3(
    input_shape = ((target_shape, target_shape, 3)),
    include_top = False,
    weights = 'imagenet',
    pooling = 'avg'
)

# Display a summary of the model architecture
inception.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(inception, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

# %%
# Freeze all layers in InceptionV3 to use it solely as a feature extractor
inception.trainable = False

# Create an input layer with shape (96, 96, 3)
inputs = tfk.Input(shape=input_shape, name='input_layer')

augmentation = tf.keras.Sequential([
    tfkl.Resizing(target_shape, target_shape),
    tfkl.Rescaling(1./127.5, offset=-1),
    tfkl.RandomZoom(0.2),
    tfkl.RandomContrast(0.5),
    tfkl.RandomBrightness(0.5),
    tfkl.RandomFlip("horizontal_and_vertical")
], name='preprocessing')

x = augmentation(inputs)

# Connect InceptionV3 to the input
x = inception(x)

x = tfkl.Dropout(0.3, name='dropout')(x)

# Add a Dense layer with 8 units and softmax activation as the classifier
outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='dense')(x)

# Create a Model connecting input and output
tl_model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

# Compile the model with Categorical Cross-Entropy loss and Lion optimizer
tl_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tl_Lion_optimizer, metrics=['accuracy'])

# Display a summary of the model architecture
tl_model.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(tl_model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

# %% [markdown]
# ## 🛠️ TRAINING

# %%
# Train the model
tl_history = tl_model.fit(
    x=X_train,
    y=y_train,
    batch_size=tl_batch_size,
    epochs=tl_epochs,
    validation_data=(X_val, y_val),
    callbacks=tl_callbacks,
    verbose = 1
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy = round(max(tl_history['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file, including final accuracy in the filename
model_filename = 'InceptionV3_TL_' + str(final_val_accuracy) + '.keras'
tl_model.save(model_filename)

# Free memory by deleting the model instance
del tl_model
# Out:
# Epoch 1/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.1171 - loss: 5.2421
# Epoch 1: val_accuracy improved from -inf to 0.12663, saving model to best.weights.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 78s 512ms/step - accuracy: 0.1171 - loss: 5.2364 - val_accuracy: 0.1266 - val_loss: 2.2198
# Epoch 2/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.1304 - loss: 3.6787
# Epoch 2: val_accuracy improved from 0.12663 to 0.19394, saving model to best.weights.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 63s 478ms/step - accuracy: 0.1303 - loss: 3.6779 - val_accuracy: 0.1939 - val_loss: 1.9507
# Epoch 3/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.1254 - loss: 3.5667
# Epoch 3: val_accuracy improved from 0.19394 to 0.33866, saving model to best.weights.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 79s 452ms/step - accuracy: 0.1255 - loss: 3.5662 - val_accuracy: 0.3387 - val_loss: 1.8276
# Epoch 4/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1258 - loss: 3.4105
# Epoch 4: val_accuracy did not improve from 0.33866
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 79s 428ms/step - accuracy: 0.1259 - loss: 3.4101 - val_accuracy: 0.3307 - val_loss: 1.7399
# Epoch 5/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.1375 - loss: 3.3493
# Epoch 5: val_accuracy did not improve from 0.33866
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 82s 426ms/step - accuracy: 0.1376 - loss: 3.3493 - val_accuracy: 0.3214 - val_loss: 1.7863
# Epoch 6/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.1362 - loss: 3.3127
# Epoch 6: val_accuracy did not improve from 0.33866
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 78s 385ms/step - accuracy: 0.1362 - loss: 3.3129 - val_accuracy: 0.2739 - val_loss: 1.9449
# Epoch 7/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.1287 - loss: 3.3762
# Epoch 7: val_accuracy improved from 0.33866 to 0.36390, saving model to best.weights.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 49s 462ms/step - accuracy: 0.1287 - loss: 3.3759 - val_accuracy: 0.3639 - val_loss: 1.7367
# Epoch 8/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.1258 - loss: 3.3627
# Epoch 8: val_accuracy did not improve from 0.36390
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 78s 427ms/step - accuracy: 0.1258 - loss: 3.3627 - val_accuracy: 0.3315 - val_loss: 1.7513
# Epoch 9/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.1296 - loss: 3.3762
# Epoch 9: val_accuracy did not improve from 0.36390
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 82s 427ms/step - accuracy: 0.1296 - loss: 3.3760 - val_accuracy: 0.2692 - val_loss: 2.3977
# Epoch 10/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1313 - loss: 3.3465
# Epoch 10: val_accuracy did not improve from 0.36390
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 82s 427ms/step - accuracy: 0.1313 - loss: 3.3465 - val_accuracy: 0.3483 - val_loss: 1.7904
# Epoch 11/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.1358 - loss: 3.3809
# Epoch 11: val_accuracy did not improve from 0.36390
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 77s 385ms/step - accuracy: 0.1358 - loss: 3.3807 - val_accuracy: 0.3572 - val_loss: 1.7734
# Epoch 12/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.1369 - loss: 3.3292
# Epoch 12: val_accuracy did not improve from 0.36390
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 45s 424ms/step - accuracy: 0.1369 - loss: 3.3293 - val_accuracy: 0.3324 - val_loss: 1.8531
# Epoch 13/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1339 - loss: 3.3329
# Epoch 13: val_accuracy improved from 0.36390 to 0.36853, saving model to best.weights.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 80s 407ms/step - accuracy: 0.1339 - loss: 3.3326 - val_accuracy: 0.3685 - val_loss: 1.7202
# Epoch 14/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.
val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 41s 382ms/step - accuracy: 0.1319 - loss: 3.4496 - val_accuracy: 0.3795 - val_loss: 1.9701
# Epoch 48/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.1322 - loss: 3.4479
# Epoch 48: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 41s 382ms/step - accuracy: 0.1322 - loss: 3.4479 - val_accuracy: 0.3496 - val_loss: 1.9579
# Epoch 49/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.1409 - loss: 3.4169
# Epoch 49: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 41s 380ms/step - accuracy: 0.1409 - loss: 3.4173 - val_accuracy: 0.3605 - val_loss: 2.1507
# Epoch 50/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.1354 - loss: 3.4413
# Epoch 50: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 41s 383ms/step - accuracy: 0.1354 - loss: 3.4411 - val_accuracy: 0.4144 - val_loss: 1.7244
# Epoch 51/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.1404 - loss: 3.4720
# Epoch 51: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 45s 424ms/step - accuracy: 0.1404 - loss: 3.4716 - val_accuracy: 0.3664 - val_loss: 1.9818
# Epoch 52/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1348 - loss: 3.3985
# Epoch 52: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 82s 428ms/step - accuracy: 0.1349 - loss: 3.3984 - val_accuracy: 0.3690 - val_loss: 1.9300
# Epoch 53/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1345 - loss: 3.4931
# Epoch 53: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 82s 428ms/step - accuracy: 0.1345 - loss: 3.4926 - val_accuracy: 0.3711 - val_loss: 1.8910
# Epoch 54/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1272 - loss: 3.4199
# Epoch 54: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 82s 428ms/step - accuracy: 0.1273 - loss: 3.4201 - val_accuracy: 0.3252 - val_loss: 2.2499
# Epoch 55/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1382 - loss: 3.4754
# Epoch 55: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 77s 385ms/step - accuracy: 0.1382 - loss: 3.4752 - val_accuracy: 0.3492 - val_loss: 2.1722
# Epoch 56/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.1370 - loss: 3.4341
# Epoch 56: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 45s 426ms/step - accuracy: 0.1370 - loss: 3.4343 - val_accuracy: 0.4056 - val_loss: 1.8460
# Epoch 57/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.1406 - loss: 3.4556
# Epoch 57: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 45s 426ms/step - accuracy: 0.1406 - loss: 3.4556 - val_accuracy: 0.4152 - val_loss: 1.6973
# Epoch 58/150
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1336 - loss: 3.4445
# Epoch 58: val_accuracy did not improve from 0.44846
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 82s 428ms/step - accuracy: 0.1335 - loss: 3.4448 - val_accuracy: 0.4030 - val_loss: 1.7488
# Final validation accuracy: 44.85%

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6))

# Plot loss for both re-trained and transfer learning models
ax1.plot(tl_history['loss'], alpha=0.3, color='#4D61E2', linestyle='--')
ax1.plot(tl_history['val_loss'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax1.set_title('Categorical Crossentropy')
ax1.legend(loc='upper left')
ax1.grid(alpha=0.3)

# Plot accuracy for both re-trained and transfer learning models
ax2.plot(tl_history['accuracy'], alpha=0.3, color='#4D61E2', linestyle='--')
ax2.plot(tl_history['val_accuracy'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax2.set_title('Accuracy')
ax2.grid(alpha=0.3)

# Adjust layout to prevent label overlap and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### INFERENCE

# %%
# Load the saved model
model_filename = "InceptionV3_TL_44.85.keras"
model = tfk.models.load_model(model_filename)

# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()

del model
# Out:
# Predictions Shape: (2796, 8)
# Accuracy score over the test set: 0.4467
# Precision score over the test set: 0.4908
# Recall score over the test set: 0.4467
# F1 score over the test set: 0.4249

# %% [markdown]
# ## 🛠️ FINE TUNING

# %% [markdown]
# ## 🧮 Define Network Parameters

# %%
# Learning rate
initial_learning_rate = 1e-4
ft_lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=10000,
    decay_rate=0.9)

# Optimazer
ft_Lion_optimizer = tfk.optimizers.Lion(learning_rate=ft_lr_schedule)

# Number of training epochs
ft_epochs = 70

# Batch size for training
ft_batch_size = 128

# Patience
ft_patience = 10


# Create an EarlyStopping callback
ft_callbacks = [
    tfk.callbacks.EarlyStopping(
        monitor='val_accuracy',
        mode='max',
        patience=ft_patience,
        restore_best_weights=True
    ),
    tfk.callbacks.ModelCheckpoint(
        filepath='best.weights.h5',
        save_best_only=True,
        save_weights_only=True,
        monitor='val_accuracy',
        mode='max',
        verbose=1
    )
]

# %% [markdown]
# ## 🛠️ Build the Model

# %%
# Load the model
model_filename = "InceptionV3_TL_44.85.keras"
ft_model = tfk.models.load_model(model_filename)

# Enable training only for Conv2D and DepthwiseConv2D layers
for i, layer in enumerate(ft_model.get_layer('inception_v3').layers[-15:]):
    if isinstance(layer, tf.keras.layers.Conv2D) or isinstance(layer, tf.keras.layers.DepthwiseConv2D):
        layer.trainable = True
        print(i, layer.name, type(layer).__name__, layer.trainable)

# Compile the model
ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=ft_Lion_optimizer, metrics=['accuracy'])

# Display a summary of the model architecture
ft_model.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(ft_model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

# %% [markdown]
# ## 🛠️ TRAINING

# %%
ft_history = ft_model.fit(
    x = X_train,
    y = y_train,
    batch_size = ft_batch_size,
    epochs = ft_epochs,
    validation_data = (X_val, y_val),
    callbacks = ft_callbacks,
    verbose = 2
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(ft_history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'InceptionV3_FT_'+str(final_val_accuracy)+'.keras'
ft_model.save(model_filename)

# Delete the model to free up resources
del ft_model
# Out:
# Epoch 1/70
#
# Epoch 1: val_accuracy improved from -inf to 0.32814, saving model to best.weights.h5
# 106/106 - 59s - 552ms/step - accuracy: 0.1345 - loss: 2.8403 - val_accuracy: 0.3281 - val_loss: 2.2185
# Epoch 2/70
#
# Epoch 2: val_accuracy improved from 0.32814 to 0.37274, saving model to best.weights.h5
# 106/106 - 47s - 447ms/step - accuracy: 0.1381 - loss: 2.5595 - val_accuracy: 0.3727 - val_loss: 1.7630
# Epoch 3/70
#
# Epoch 3: val_accuracy improved from 0.37274 to 0.39840, saving model to best.weights.h5
# 106/106 - 82s - 774ms/step - accuracy: 0.1404 - loss: 2.4764 - val_accuracy: 0.3984 - val_loss: 1.7261
# Epoch 4/70
#
# Epoch 4: val_accuracy did not improve from 0.39840
# 106/106 - 79s - 749ms/step - accuracy: 0.1425 - loss: 2.4133 - val_accuracy: 0.3891 - val_loss: 1.7046
# Epoch 5/70
#
# Epoch 5: val_accuracy improved from 0.39840 to 0.42659, saving model to best.weights.h5
# 106/106 - 84s - 792ms/step - accuracy: 0.1405 - loss: 2.3849 - val_accuracy: 0.4266 - val_loss: 1.6121
# Epoch 6/70
#
# Epoch 6: val_accuracy improved from 0.42659 to 0.44426, saving model to best.weights.h5
# 106/106 - 42s - 401ms/step - accuracy: 0.1400 - loss: 2.3686 - val_accuracy: 0.4443 - val_loss: 1.6018
# Epoch 7/70
#
# Epoch 7: val_accuracy did not improve from 0.44426
# 106/106 - 45s - 422ms/step - accuracy: 0.1428 - loss: 2.3748 - val_accuracy: 0.4207 - val_loss: 1.6942
# Epoch 8/70
#
# Epoch 8: val_accuracy did not improve from 0.44426
# 106/106 - 82s - 775ms/step - accuracy: 0.1417 - loss: 2.3732 - val_accuracy: 0.3744 - val_loss: 1.6960
# Epoch 9/70
#
# Epoch 9: val_accuracy did not improve from 0.44426
# 106/106 - 82s - 772ms/step - accuracy: 0.1389 - loss: 2.3804 - val_accuracy: 0.4102 - val_loss: 1.5875
# Epoch 10/70
#
# Epoch 10: val_accuracy improved from 0.44426 to 0.44804, saving model to best.weights.h5
# 106/106 - 85s - 797ms/step - accuracy: 0.1447 - loss: 2.3783 - val_accuracy: 0.4480 - val_loss: 1.5219
# Epoch 11/70
#
# Epoch 11: val_accuracy did not improve from 0.44804
# 106/106 - 79s - 748ms/step - accuracy: 0.1427 - loss: 2.3653 - val_accuracy: 0.4245 - val_loss: 1.5797
# Epoch 12/70
#
# Epoch 12: val_accuracy improved from 0.44804 to 0.46824, saving model to best.weights.h5
# 106/106 - 84s - 794ms/step - accuracy: 0.1448 - loss: 2.3595 - val_accuracy: 0.4682 - val_loss: 1.4236
# Epoch 13/70
#
# Epoch 13: val_accuracy improved from 0.46824 to 0.48633, saving model to best.weights.h5
# 106/106 - 47s - 448ms/step - accuracy: 0.1421 - loss: 2.3651 - val_accuracy: 0.4863 - val_loss: 1.4380
# Epoch 14/70
#
# Epoch 14: val_accuracy did not improve from 0.48633
# 106/106 - 80s - 752ms/step - accuracy: 0.1405 - loss: 2.3569 - val_accuracy: 0.4821 - val_loss: 1.4805
# Epoch 15/70
#
# Epoch 15: val_accuracy improved from 0.48633 to 0.50778, saving model to best.weights.h5
# 106/106 - 42s - 398ms/step - accuracy: 0.1420 - loss: 2.3321 - val_accuracy: 0.5078 - val_loss: 1.3789
# Epoch 16/70
#
# Epoch 16: val_accuracy improved from 0.50778 to 0.51620, saving model to best.weights.h5
# 106/106 - 83s - 781ms/step - accuracy: 0.1447 - loss: 2.3102 - val_accuracy: 0.5162 - val_loss: 1.3550
# Epoch 17/70
#
# Epoch 17: val_accuracy improved from 0.51620 to 0.53597, saving model to best.weights.h5
# 106/106 - 82s - 777ms/step - accuracy: 0.1439 - loss: 2.3260 - val_accuracy: 0.5360 - val_loss: 1.3064
# Epoch 18/70
#
# Epoch 18: val_accuracy did not improve from 0.53597
# 106/106 - 45s - 421ms/step - accuracy: 0.1385 - loss: 2.3101 - val_accuracy: 0.4001 - val_loss: 1.9224
# Epoch 19/70
#
# Epoch 19: val_accuracy did not improve from 0.53597
# 106/106 - 78s - 735ms/step - accuracy: 0.1453 - loss: 2.3218 - val_accuracy: 0.4939 - val_loss: 1.4452
# Epoch 20/70
#
# Epoch 20: val_accuracy did not improve from 0.53597
# 106/106 - 45s - 423ms/step - accuracy: 0.1444 - loss: 2.3333 - val_accuracy: 0.5158 - val_loss: 1.3112
# Epoch 21/70
#
# Epoch 21: val_accuracy did not improve from 0.53597
# 106/106 - 41s - 382ms/step - accuracy: 0.1414 - loss: 2.3424 - val_accuracy: 0.5208 - val_loss: 1.3919
# Epoch 22/70
#
# Epoch 22: val_accuracy improved from 0.53597 to 0.55532, saving model to best.weights.h5
# 106/106 - 46s - 433ms/step - accuracy: 0.1423 - loss: 2.3183 - val_accuracy: 0.5553 - val_loss: 1.2713
# Epoch 23/70
#
# Epoch 23: val_accuracy did not improve from 0.55532
# 106/106 - 81s - 769ms/step - accuracy: 0.1408 - loss: 2.3238 - val_accuracy: 0.5284 - val_loss: 1.3181
# Epoch 24/70
#
# Epoch 24: val_accuracy did not improve from 0.55532
# 106/106 - 45s - 422ms/step - accuracy: 0.1389 - loss: 2.3176 - val_accuracy: 0.5103 - val_loss: 1.4250
# Epoch 25/70
#
# Epoch 25: val_accuracy did not improve from 0.55532
# 106/106 - 78s - 735ms/step - accuracy: 0.1406 - loss: 2.3227 - val_accuracy: 0.4569 - val_loss: 1.7533
# Epoch 26/70
#
# Epoch 26: val_accuracy improved from 0.55532 to 0.58519, saving model to best.weights.h5
# 106/106 - 47s - 444ms/step - accuracy: 0.1387 - loss: 2.3403 - val_accuracy: 0.5852 - val_loss: 1.2123
# Epoch 27/70
#
# Epoch 27: val_accuracy did not improve from 0.58519
# 106/106 - 45s - 425ms/step - accuracy: 0.1396 - loss: 2.3427 - val_accuracy: 0.5591 - val_loss: 1.1961
# Epoch 28/70
#
# Epoch 28: val_accuracy did not improve from 0.58519
# 106/106 - 45s - 425ms/step - accuracy: 0.1405 - loss: 2.3260 - val_accuracy: 0.5074 - val_loss: 1.2612
# Epoch 29/70
#
# Epoch 29: val_accuracy did not improve from 0.58519
# 106/106 - 82s - 775ms/step - accuracy: 0.1452 - loss: 2.3299 - val_accuracy: 0.5377 - val_loss: 1.2442
# Epoch 30/70
#
# Epoch 30: val_accuracy did not improve from 0.58519
# 106/106 - 77s - 729ms/step - accuracy: 0.1484 - loss: 2.3147 - val_accuracy: 0.5377 - val_loss: 1.2613
# Epoch 31/70
#
# Epoch 31: val_accuracy did not improve from 0.58519
# 106/106 - 41s - 384ms/step - accuracy: 0.1416 - loss: 2.3194 - val_accuracy: 0.5721 - val_loss: 1.2290
# Epoch 32/70
#
# Epoch 32: val_accuracy improved from 0.58519 to 0.59066, saving model to best.weights.h5
# 106/106 - 47s - 446ms/step - accuracy: 0.1427 - loss: 2.3186 - val_accuracy: 0.5907 - val_loss: 1.1455
# Epoch 33/70
#
# Epoch 33: val_accuracy did not improve from 0.59066
# 106/106 - 76s - 716ms/step - accuracy: 0.1397 - loss: 2.3222 - val_accuracy: 0.5284 - val_loss: 1.3412
# Epoch 34/70
#
# Epoch 34: val_accuracy did not improve from 0.59066
# 106/106 - 45s - 425ms/step - accuracy: 0.1386 - loss: 2.3469 - val_accuracy: 0.5621 - val_loss: 1.1752
# Epoch 35/70
#
# Epoch 35: val_accuracy did not improve from 0.59066
# 106/106 - 40s - 382ms/step - accuracy: 0.1412 - loss: 2.3493 - val_accuracy: 0.5814 - val_loss: 1.1683
# Epoch 36/70
#
# Epoch 36: val_accuracy did not improve from 0.59066
# 106/106 - 45s - 426ms/step - accuracy: 0.1344 - loss: 2.3315 - val_accuracy: 0.5684 - val_loss: 1.1515
# Epoch 37/70
#
# Epoch 37: val_accuracy did not improve from 0.59066
# 106/106 - 78s - 734ms/step - accuracy: 0.1429 - loss: 2.3383 - val_accuracy: 0.5326 - val_loss: 1.2198
# Epoch 38/70
#
# Epoch 38: val_accuracy did not improve from 0.59066
# 106/106 - 45s - 426ms/step - accuracy: 0.1421 - loss: 2.3289 - val_accuracy: 0.5520 - val_loss: 1.3091
# Epoch 39/70
#
# Epoch 39: val_accuracy did not improve from 0.59066
# 106/106 - 82s - 773ms/step - accuracy: 0.1423 - loss: 2.3270 - val_accuracy: 0.5881 - val_loss: 1.2271
# Epoch 40/70
#
# Epoch 40: val_accuracy did not improve from 0.59066
# 106/106 - 82s - 774ms/step - accuracy: 0.1405 - loss: 2.3343 - val_accuracy: 0.5183 - val_loss: 1.5414
# Epoch 41/70
#
# Epoch 41: val_accuracy improved from 0.59066 to 0.59950, saving model to best.weights.h5
# 106/106 - 82s - 772ms/step - accuracy: 0.1413 - loss: 2.3268 - val_accuracy: 0.5995 - val_loss: 1.1599
# Epoch 42/70
#
# Epoch 42: val_accuracy did not improve from 0.59950
# 106/106 - 40s - 379ms/step - accuracy: 0.1418 - loss: 2.3332 - val_accuracy: 0.5759 - val_loss: 1.1607
# Epoch 43/70
#
# Epoch 43: val_accuracy did not improve from 0.59950
# 106/106 - 45s - 428ms/step - accuracy: 0.1461 - loss: 2.3378 - val_accuracy: 0.5721 - val_loss: 1.1421
# Epoch 44/70
#
# Epoch 44: val_accuracy improved from 0.59950 to 0.61127, saving model to best.weights.h5
# 106/106 - 85s - 798ms/step - accuracy: 0.1496 - loss: 2.3195 - val_accuracy: 0.6113 - val_loss: 1.0534
# Epoch 45/70
#
# Epoch 45: val_accuracy improved from 0.61127 to 0.61843, saving model to best.weights.h5
# 106/106 - 78s - 738ms/step - accuracy: 0.1429 - loss: 2.3079 - val_accuracy: 0.6184 - val_loss: 1.0395
# Epoch 46/70
#
# Epoch 46: val_accuracy did not improve from 0.61843
# 106/106 - 83s - 786ms/step - accuracy: 0.1416 - loss: 2.3181 - val_accuracy: 0.5944 - val_loss: 1.2406
# Epoch 47/70
#
# Epoch 47: val_accuracy did not improve from 0.61843
# 106/106 - 82s - 772ms/step - accuracy: 0.1503 - loss: 2.3177 - val_accuracy: 0.5860 - val_loss: 1.1230
# Epoch 48/70
#
# Epoch 48: val_accuracy did not improve from 0.61843
# 106/106 - 82s - 772ms/step - accuracy: 0.1517 - loss: 2.3343 - val_accuracy: 0.5717 - val_loss: 1.1043
# Epoch 49/70
#
# Epoch 49: val_accuracy did not improve from 0.61843
# 106/106 - 82s - 774ms/step - accuracy: 0.1422 - loss: 2.3475 - val_accuracy: 0.5351 - val_loss: 1.2195
# Epoch 50/70
#
# Epoch 50: val_accuracy did not improve from 0.61843
# 106/106 - 82s - 773ms/step - accuracy: 0.1479 - loss: 2.3180 - val_accuracy: 0.6037 - val_loss: 1.1592
# Epoch 51/70
#
# Epoch 51: val_accuracy did not improve from 0.61843
# 106/106 - 78s - 732ms/step - accuracy: 0.1465 - loss: 2.3049 - val_accuracy: 0.5852 - val_loss: 1.1258
# Epoch 52/70
#
# Epoch 52: val_accuracy did not improve from 0.61843
# 106/106 - 45s - 423ms/step - accuracy: 0.1488 - loss: 2.3210 - val_accuracy: 0.5583 - val_loss: 1.1504
# Epoch 53/70
#
# Epoch 53: val_accuracy did not improve from 0.61843
# 106/106 - 82s - 777ms/step - accuracy: 0.1503 - loss: 2.3291 - val_accuracy: 0.5772 - val_loss: 1.1047
# Epoch 54/70
#
# Epoch 54: val_accuracy did not improve from 0.61843
# 106/106 - 82s - 772ms/step - accuracy: 0.1442 - loss: 2.3231 - val_accuracy: 0.5242 - val_loss: 1.2137
# Epoch 55/70
#
# Epoch 55: val_accuracy did not improve from 0.61843
# 106/106 - 82s - 772ms/step - accuracy: 0.1472 - loss: 2.3388 - val_accuracy: 0.5255 - val_loss: 1.5843
# Final validation accuracy: 61.84%

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6))

# Plot categorical cross-entropy loss for both Transfer Learning and Fine Tuning stages
ax1.plot(tl_history['loss'], alpha=0.3, color='#4D61E2', linestyle='--')
ax1.plot(tl_history['val_loss'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax1.plot(ft_history['loss'], alpha=0.3, color='#408537', linestyle='--')
ax1.plot(ft_history['val_loss'], label='Fine Tuning', alpha=0.8, color='#408537')
ax1.set_title('Categorical Crossentropy')
ax1.legend(loc='upper left')
ax1.grid(alpha=0.3)

# Plot accuracy for both Transfer Learning and Fine Tuning stages
ax2.plot(tl_history['accuracy'], alpha=0.3, color='#4D61E2', linestyle='--')
ax2.plot(tl_history['val_accuracy'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax2.plot(ft_history['accuracy'], alpha=0.3, color='#408537', linestyle='--')
ax2.plot(ft_history['val_accuracy'], label='Fine Tuning', alpha=0.8, color='#408537')
ax2.set_title('Accuracy')
ax2.set_ylim([min(tl_history['val_accuracy']) * 0.95, max(ft_history['val_accuracy']) * 1.05])
ax2.grid(alpha=0.3)

# Adjust layout to prevent overlap and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## INFERENCE

# %%
# Load the saved model
model_filename = "InceptionV3_FT_61.84.keras"
model = tfk.models.load_model(model_filename)

# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (2796, 8)
# Accuracy score over the test set: 0.6241
# Precision score over the test set: 0.644
# Recall score over the test set: 0.6241
# F1 score over the test set: 0.6169

# %% [markdown]
# ##SUBMISSION

# %%
# %%writefile model.py
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl


class Model:
    def __init__(self):
        """
        Initialize the internal state of the model. Note that the __init__
        method cannot accept any arguments.

        The following is an example loading the weights of a pre-trained
        model.
        """
        self.neural_network = tfk.models.load_model("InceptionV3_FT_61.84.keras")

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,). Therefore, outputs must no be one-hot
        encoded.

        The following is an example of a prediction from the pre-trained model
        loaded in the __init__ method.
        """
        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)
        return preds
# Out:
# Writing model.py

# %%
from datetime import datetime
filename = f'submission_{datetime.now().strftime("%y%m%d_%H%M%S")}.zip'

# Add files to the zip command if needed
# !zip {filename} model.py InceptionV3_FT_61.84.keras

from google.colab import files
files.download(filename)
# Out:
#   adding: model.py (deflated 55%)
#   adding: InceptionV3_FT_61.84.keras (deflated 8%)
